# %%
import pandas as pd
pd.set_option('display.max_columns', None)

import numpy as np

import warnings
warnings.filterwarnings('ignore')

#Functions
from src.funk import Funk

# %%
pib_15_19 = pd.read_excel('raw_data/pib_muni_2019-2015.xls')

pib_15_19.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  195 non-null    object
#  1   Unnamed: 1  192 non-null    float64
#  2   Unnamed: 2  192 non-null    float64
#  3   Unnamed: 3  192 non-null    object
#  4   Unnamed: 4  192 non-null    object
#  5   Unnamed: 5  192 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 40.2 KB

# %%
pib_15_19.head(10)
# Out:
#                                           Unnamed: 0   Unnamed: 1  \
# 0                                                NaN          NaN
# 1                                                NaN          NaN
# 2                                                NaN          NaN
# 3                                                NaN          NaN
# 4  Producto Interior Bruto Municipal por zonas es...          NaN
# 5                                                NaN          NaN
# 6                                        Miles Euros          NaN
# 7                                                NaN       2015.0
# 8                                                NaN          NaN
# 9                                Comunidad de Madrid  201770928.0
#
#     Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5
# 0          NaN        NaN        NaN        NaN
# 1          NaN        NaN        NaN        NaN
# 2          NaN        NaN        NaN        NaN
# ...

# %%
pib_11_09 = pd.read_excel('raw_data/pib_muni_2011-2009.ods', engine="odf")

pib_11_09.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 204 entries, 0 to 203
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  195 non-null    object
#  1   Unnamed: 1  192 non-null    object
#  2   Unnamed: 2  192 non-null    object
#  3   Unnamed: 3  192 non-null    object
# dtypes: object(4)
# memory usage: 36.5 KB

# %%
pib_11_09.head(10)
# Out:
#                                           Unnamed: 0 Unnamed: 1 Unnamed: 2  \
# 0                                                NaN        NaN        NaN
# 1                                                NaN        NaN        NaN
# 2  Producto Interior Bruto Municipal por zonas es...        NaN        NaN
# 3                                                NaN        NaN        NaN
# 4                                     Miles de euros        NaN        NaN
# 5                                                NaN   2009 (p)   2010 (a)
# 6                                                NaN        NaN        NaN
# 7                                Comunidad de Madrid  194485387  194720981
# 8                                                NaN        NaN        NaN
# 9                                Municipio de Madrid  119899983  119460025
#
#   Unnamed: 3
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5   2011 (a)
# 6        NaN
# 7  200100238
# ...

# %%
pib_09_02 = pd.read_excel('raw_data/pib_muni_2009-2002.ods', engine="odf")

pib_09_02.info(memory_usage='deep')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 207 entries, 0 to 206
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Unnamed: 0   195 non-null    object
#  1   Unnamed: 1   4 non-null      object
#  2   Unnamed: 2   190 non-null    object
#  3   Unnamed: 3   192 non-null    float64
#  4   Unnamed: 4   192 non-null    float64
#  5   Unnamed: 5   192 non-null    float64
#  6   Unnamed: 6   192 non-null    float64
#  7   Unnamed: 7   192 non-null    float64
#  8   Unnamed: 8   192 non-null    float64
#  9   Unnamed: 9   192 non-null    object
#  10  Unnamed: 10  192 non-null    object
# dtypes: float64(6), object(5)
# memory usage: 56.3 KB

# %%
pib_09_02.head(10)
# Out:
#                                           Unnamed: 0  \
# 0                                                NaN
# 1                                                NaN
# 2  Indicador del PIB por zonas estadísticas y por...
# 3                                                NaN
# 4                                     Miles de euros
# 5                                             Código
# 6                                                NaN
# 7                                                NaN
# 8                                                NaN
# 9                                                NaN
#
#                   Unnamed: 1 Unnamed: 2    Unnamed: 3    Unnamed: 4  \
# 0                        NaN        NaN           NaN           NaN
# 1                        NaN        NaN           NaN           NaN
# 2                        NaN        NaN           NaN           NaN
# 3                        NaN        NaN           NaN           NaN
# ...
